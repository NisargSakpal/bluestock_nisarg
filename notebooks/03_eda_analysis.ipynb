# %%
print("hello niisarg")
# Out:
# hello niisarg

# %%
import pandas as pd
import plotly.express as px

nav = pd.read_csv("../data/processed/nav_history_clean.csv")

nav["date"] = pd.to_datetime(nav["date"])

# Use first 5 funds for testing
funds = nav["amfi_code"].unique()[:5]

nav_small = nav[nav["amfi_code"].isin(funds)]

fig = px.line(
    nav_small,
    x="date",
    y="nav",
    color="amfi_code",
    title="NAV Trend - First 5 Funds"
)

fig.show()

# %%
import pandas as pd
import plotly.express as px

nav = pd.read_csv("../data/processed/nav_history_clean.csv")
nav["date"] = pd.to_datetime(nav["date"])

fig = px.line(
    nav,
    x="date",
    y="nav",
    color="amfi_code",
    title="Daily NAV Trend for All Schemes (2022–2026)"
)

fig.add_vrect(
    x0="2023-01-01",
    x1="2023-12-31",
    annotation_text="2023 Bull Run",
    fillcolor="green",
    opacity=0.15
)

fig.add_vrect(
    x0="2024-01-01",
    x1="2024-12-31",
    annotation_text="2024 Market Correction",
    fillcolor="red",
    opacity=0.10
)

fig.show()

# %% [markdown]
# Finding 1 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

age_counts = transactions["age_group"].value_counts()

fig = px.pie(
    values=age_counts.values,
    names=age_counts.index,
    title="Investor Age Group Distribution"
)

fig.show()

# %% [markdown]
# Finding 2(EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

gender_counts = transactions["gender"].value_counts()

fig = px.pie(
    values=gender_counts.values,
    names=gender_counts.index,
    title="Investor Gender Distribution"
)

fig.show()

# %% [markdown]
# Finding 3 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

sip_data = transactions[transactions["transaction_type"] == "SIP"]

fig = px.box(
    sip_data,
    x="age_group",
    y="amount_inr",
    title="SIP Amount Distribution by Age Group"
)

fig.show()

# %% [markdown]
# Finding 4 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

state_sip = (
    transactions[transactions["transaction_type"] == "SIP"]
    .groupby("state")["amount_inr"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

fig = px.bar(
    state_sip,
    x="amount_inr",
    y="state",
    orientation="h",
    title="Total SIP Amount by State"
)

fig.show()

# %% [markdown]
# Finding 5 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

tier_counts = transactions["city_tier"].value_counts()

fig = px.pie(
    values=tier_counts.values,
    names=tier_counts.index,
    title="T30 vs B30 Investor Distribution"
)

fig.show()

# %% [markdown]
# Finding 6 (EDA)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

nav = pd.read_csv("../data/processed/nav_history_clean.csv")

# Select first 10 funds
top10 = nav["amfi_code"].unique()[:10]

nav = nav[nav["amfi_code"].isin(top10)]

# Convert date
nav["date"] = pd.to_datetime(nav["date"])

# Pivot table
pivot = nav.pivot(
    index="date",
    columns="amfi_code",
    values="nav"
)

# Daily returns
returns = pivot.pct_change()

# Correlation matrix
corr_matrix = returns.corr()

plt.figure(figsize=(10,8))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm"
)

plt.title("NAV Return Correlation Matrix")
plt.show()

# %% [markdown]
# Finding 7 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

txn_counts = transactions["transaction_type"].value_counts()

fig = px.pie(
    values=txn_counts.values,
    names=txn_counts.index,
    title="Transaction Type Distribution"
)

fig.show()

# %% [markdown]
# Finding 8 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

txn_counts = transactions["transaction_type"].value_counts()

fig = px.pie(
    values=txn_counts.values,
    names=txn_counts.index,
    title="Transaction Type Distribution"
)

fig.show()

# %% [markdown]
# Finding 9 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

fig = px.histogram(
    transactions,
    x="annual_income_lakh",
    nbins=20,
    title="Investor Annual Income Distribution"
)

fig.show()

# %% [markdown]
# Finding 10 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

sip = transactions[
    transactions["transaction_type"] == "Sip"
]

avg_sip = (
    sip.groupby("age_group")["amount_inr"]
    .mean()
    .reset_index()
)

fig = px.bar(
    avg_sip,
    x="age_group",
    y="amount_inr",
    title="Average SIP Amount by Age Group"
)

fig.show()

# %% [markdown]
# Finding 11 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

mode_count = transactions["payment_mode"].value_counts()

fig = px.pie(
    values=mode_count.values,
    names=mode_count.index,
    title="Payment Mode Distribution"
)

fig.show()

# %% [markdown]
# Finding 12 (EDA)

# %%
import pandas as pd
import plotly.express as px

transactions = pd.read_csv("../data/processed/investor_transactions_clean.csv")

kyc = transactions["kyc_status"].value_counts()

fig = px.pie(
    values=kyc.values,
    names=kyc.index,
    title="KYC Status Distribution"
)

fig.show()

# %% [markdown]
# Finding 13 (EDA)

# %%
import pandas as pd
import plotly.express as px

funds = pd.read_csv("../data/raw/01_fund_master.csv")

cat = funds["category"].value_counts()

fig = px.bar(
    x=cat.index,
    y=cat.values,
    title="Fund Category Distribution"
)

fig.show()

# %% [markdown]
# Finding 14 (EDA)

# %%
import pandas as pd
import plotly.express as px

funds = pd.read_csv("../data/raw/01_fund_master.csv")

risk = funds["risk_category"].value_counts()

fig = px.pie(
    values=risk.values,
    names=risk.index,
    title="Risk Category Distribution"
)

fig.show()

# %% [markdown]
# Finding 15 (EDA)

# %%
import pandas as pd
import plotly.express as px

funds = pd.read_csv("../data/raw/01_fund_master.csv")

house = (
    funds.groupby("fund_house")["scheme_name"]
    .count()
    .sort_values(ascending=False)
    .reset_index()
)

fig = px.bar(
    house,
    x="fund_house",
    y="scheme_name",
    title="Number of Schemes by Fund House"
)

fig.show()

# %% [markdown]
# Finding 16 (EDA)
